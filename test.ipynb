# %%
import torch

# Load the model checkpoint
checkpoint = torch.load('out-shakespeare-char/ckpt.pt')

# Print the keys in the loaded checkpoint dictionary
print(checkpoint.keys())
# Out:
# dict_keys(['model', 'optimizer', 'model_args', 'iter_num', 'best_val_loss', 'config'])

# %%
# !python sample.py --out_dir=out-shakespeare-char
# Out:
# Overriding: out_dir = out-shakespeare-char
# number of parameters: 10.65M
# Loading meta from data\shakespeare_char\meta.pkl...
#
#
# Clown:
# So, who is he would through the best of Signior Marcius
# have the cepture of your petition.
#
# AEdile:
# What's a maze of those proof in his tomb. This
# that might send in the sea drop of the people, how that
# with lind of his husband with a childish him yet home.
# I was patiently to thy woes to again Wiltshire, and thee at
# thy brother had no most more for the king to thy fault; and thought
# thy fled at the day of York and thou art too discharged to the helm.
#
# GREGORY:
# Urged your battle man a wi
# ---------------
#
# Men part of marriage and his loss
# That have so put forth and made we would live.
#
# BUCKINGHAM:
# Thou couldst thou at mighty mother,
# Which in some under when moveth it is.
#
# LADY CAPULET:
# Why, my lord, how now, for Lancaster Claudio!
#
# Nurse:
# Why do you not laugh? how a world will under me!
#
# JULIET:
# How now, stirs, and this almost honour!
#
# Nurse:
# My lord, I would have set thee in it.
#
# Nurse:
# The lay me will take it be that to be glad,
# Behold my purse. O, the villain that it will
# Tell the queen's body
# ---------------
#
# Men take me with all the two comes. She is not a dog, not
# take a money where he gives me weeping, sir; being times, it
# should this fair wind child or branes, wise I have
# a cause of policy.
#
# Clown:
# I thought I am a sorrow sir, but and so shall eaten
# grieve a determined He was and last marriage too.
#
# Shepherd:
# He hath not much here a barrage of it is standed.
#
# DUKE VINCENTIO:
# I am here been so much one store; that lave both which
# have I an earth made in tears of claim first, and masters, holding
# t
# ---------------
#
# The sleep of Brintague, her bloody sons and division
# Shall rest! We are full of full of issue
# More than drinks of my Lord Hastings, Diom's redeems
# Than her brother and as it is his love
# Shall make the best of the hardy labour in his breast,
# Before I have cry, thou within the linster's shame,
# That was mad for Bolingbroke's service,
# Your like a soul's words in a sceptre's children,
# That thy poor hap now wons and John of Gaunt,
# And, Juliet parting murder shake's face,
# That shame to heaven my hands
# ---------------
#
# BUCKINGHAM:
# Then, her lords, and looking in the ragger of York;
# And that must have brought conceived his sons,
# Shall the labour of the tread amble slain;
# Not to swift mine own unmanner'd by them one;
# And young man many holds the hand of men.
# If your loving pack of Montague,
# To this watery sedge and advised,
# That all no approbation of some blood
# That make me such more shot-play. See, good grave men.
#
# DUKE VINCENTIO:
# Ay, and what a thing affection? that of reheart
# The supperous profit of his servi
# ---------------
#
#
# MENENIUS:
# Here's a man to a sit, he must take him in his
# A peace of private, a month of his noble action, and
# By all the powers of his from me hate error, his soldiers
# That blasts me with ingers, like his face, to his wife,
# The commons of the wholesome counsel that bitter shooks his
# To the day of hate his daughter.
#
# AUTOLYCUS:
# All the poor time will be coldered. I will not
# tell thy contraction would be a little corse. I am proclaims
# And hate the beggar's hands there, beholding a right
# More than
# ---------------
#
# Shepherd; but the friar, and filling she,
# A shrink which of itself. I am a short.
#
# FLORIZEL:
# Here's a are free for she brings,
# Whose honours in pains, and shame, a very good
# To every man or his drunk is a born.
#
# CAMILLO:
# Here's some comes home.
#
# CAMILLO:
# Here's unraged as most seat
# The when within his father's journey, here.
#
# LEONTES:
#
# LEONTES:
# Provost, round the day he hated me remains
# Your children to make one advantage to the fearful spirit:
# For I cannot be put for me.
# I'll warrant you.
#
# ANTI
# ---------------
#
# I have heard me in no foe, or why, now I have
# A damned silk to the king, heavens of the man
# So take both and play'd your power to play,
# But an alliant pity and a shored like a breath,
# And devotion when you shall have done marriage.
#
# FLORIZEL:
# There she is ever her singular be not too shine.
#
# CAMILLO:
# A goodly time, I am your cousin
# With deserved tears, your hate your grace in me; the manks--
# And here at your honour's sword and content
# To in the advantage of your queen with a limble sword
# With sp
# ---------------
#
#
# LEONTES:
# The new is not the people's desperation like
# His since that his beheld infolding.
#
# LEONTES:
# He hath sturb'd him;
# And the first noble Apollo,
# Stale hath been done that his.
#
# PAULINA:
# I did remain between your names,
# Let me berrift with the shore. The away.
# Angelo he banished!
# Him here is a time, and a fellow man's death;
# And life gallows the pastise for a but ill-beggar,
# Continue the gentleman to be so money?
#
# LEONTES:
# Within, the hand at supper us.
#
# PAULINA:
# No, by my hand of grief and
# ---------------
#
# How changed that resolve thee revell'd for that I am here leave.
#
# CAPULET:
# What, then?
#
# CAPULET:
# Bring thee, your thumb, be tell me, that it is hit.
#
# MARCIUS:
# Yet, marry, sir.
#
# CAMILLO:
# I'll stay to the people's son will acord
# to make a mine own.
#
# MARCIUS:
# What is it needs?
#
# MENENIUS:
# You have said it as the has proud as your time a vile must
# That force of voices and old truth and will be thing to supposed
# In so expedient of dear Tiber's hand,
# To see the fools till have a lickle course
# To see he
# ---------------
